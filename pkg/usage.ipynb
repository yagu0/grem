# %%
import grem, time

gr = grem.make_random_tree(5000, 0, 150)
grem.plot_graph(g=gr)
for i in range(20):
    grem.spring_layout(gr, 10, 300)
    grem.plot_graph(g=gr).save(f"out_{i}.png")
    #time.sleep(1)

# %%
grem.plot_graph(g=gr)
