# %%
import grem

# %%
g = grem.make_random_binary_tree(100, 100, 32)

# %%
grem.plot_graph(g=g)

# %%
grem.spring_layout(g, 100)

# %%
grem.plot_graph(g=g)

# %%
g.nodes[2]
# Out:
# {'id': 2,
#  'x': 1120.072909383436,
#  'y': 430.7086445547306,
#  'degree': 3,
#  'neighbors': [0, 3, 4]}

# %%
g2 = grem.make_random_tree(100, 0, 100)

# %%
grem.spring_layout(g2, 100)

# %%
grem.plot_graph(g=g2)
