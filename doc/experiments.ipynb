# %%
import grem
g = grem.make_random_nary_tree(100, 1.5, 100, 32)
grem.spring_layout(g, 500, 10, 0.01)
# 0.1s par sommet
ani = grem.animate_graph(g=g, inter_node_time=0.1)
# ou durée totale de 8s
#ani = grem.animate_graph(g=g, total_time=8.0)

# %%
import grem

# %%
g = grem.make_random_binary_tree(100, 100, 32)

# %%
g = grem.make_random_nary_tree(100, 1.5, 100, 32)

# %%
grem.plot_graph(g=g)

# %%
grem.animate_graph(g=g)

# %%
g.nodes[1]["color"]

# %%
coords = [(node["x"], node["y"]) for node in g.nodes]

# %%
coords[2]

# %%
grem.spring_layout(g, 500, 10, 0.03, 0.25, 0.20)

# %%
grem.plot_graph(g=g)

# %%
g2 = grem.make_random_tree(100, 0, 100)

# %%
grem.spring_layout(g2, 500)

# %%
grem.plot_graph(g=g2)

# %%
g3 = grem.make_random_tree(10000, 0, 100)

# %%
grem.spring_layout(g3, 500, 10, 0.01)

# %%
grem.plot_graph(g=g3)

# %%
g4 = grem.make_random_binary_tree(10000, 100, 32)

# %%
grem.spring_layout(g4, 500)

# %%
grem.plot_graph(g=g4)
